# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("/home/banga/Desktop/datamining/beta/beta_data_stat.csv")

# %%
data
# Out:
#        Equity       KCB    UCHUMI   BAMBURI       BAT      EABL    SASINI  \
# 0    4.720000  4.350000  2.000000  5.000000  5.830000  1.870000  6.690000
# 1    4.930000  4.230000  2.020000  5.000000  5.520000  1.840000  6.560000
# 2    4.480000  4.230000  2.080000  5.000000  5.520000  1.900000  6.250000
# 3    4.140000  4.020000  2.080000  5.000000  5.810000  1.940000  5.570000
# 4    3.890000  3.670000  2.480000  5.120000  5.700000  2.120000  5.280000
# 5    3.300000  3.700000  2.390000  5.120000  6.000000  2.120000  1.450000
# 6    3.280000  3.540000  2.320000  5.070000  5.960000  2.260000  1.450000
# 7    3.210000  3.510000  2.400000  5.070000  5.600000  2.250000  1.470000
# 8    3.020000  3.480000  2.410000  5.100000  6.400000  2.080000  1.470000
# 9    3.260000  3.450000  3.330000  5.340000  6.250000  2.120000  1.410000
# 10   2.970000  3.420000  3.260000  5.310000  6.000000  2.120000  1.440000
# 11   3.000000  3.450000  3.210000  5.420000  5.970000  2.040000  1.440000
# ...

# %%
data.MARKET.std() *data.MARKET.std()
# Out:
# 0.20751441562851791

# %%
data.MARKET.var()
# Out:
# 0.20751441562851788

# %%
covariance=data.cov()
covariance=covariance.MARKET
data.cov()
# Out:
#            Equity       KCB    UCHUMI   BAMBURI       BAT      EABL    SASINI  \
# Equity   0.481030  0.338933  0.011642 -0.065487  0.100822  0.013956  0.185330
# KCB      0.338933  0.413730 -0.075035 -0.058370  0.119689  0.006384  0.132152
# UCHUMI   0.011642 -0.075035  0.878383  0.219434 -0.201607  0.050650 -0.057074
# BAMBURI -0.065487 -0.058370  0.219434  0.855768 -0.245102 -0.029327 -0.273560
# BAT      0.100822  0.119689 -0.201607 -0.245102  0.652552  0.033019 -0.017901
# EABL     0.013956  0.006384  0.050650 -0.029327  0.033019  0.028269  0.007552
# SASINI   0.185330  0.132152 -0.057074 -0.273560 -0.017901  0.007552  1.459297
# SAFAR    0.018113 -0.013556  0.215543  0.362122 -0.051762  0.027614 -0.141810
# NMG      0.161743  0.037061  0.452732  0.730030  0.165796  0.088616 -0.197810
# SCB      0.223290  0.159166  0.399912  0.654030  0.099552  0.093214 -0.059942
# MARKET   0.146937  0.106015  0.189458  0.214954  0.065506  0.031995  0.103623
#
# ...

# %%
cov_data=(covariance)/data.MARKET.var()

# %%
data.head()
# Out:
#    Equity   KCB  UCHUMI  BAMBURI   BAT  EABL  SASINI  SAFAR   NMG   SCB  \
# 0    4.72  4.35    2.00     5.00  5.83  1.87    6.69   2.87  3.16  4.11
# 1    4.93  4.23    2.02     5.00  5.52  1.84    6.56   2.64  3.18  4.08
# 2    4.48  4.23    2.08     5.00  5.52  1.90    6.25   2.70  3.18  4.44
# 3    4.14  4.02    2.08     5.00  5.81  1.94    5.57   2.49  3.09  4.11
# 4    3.89  3.67    2.48     5.12  5.70  2.12    5.28   2.82  3.16  4.25
#
#    MARKET
# 0   4.060
# 1   4.000
# 2   3.978
# 3   3.825
# 4   3.849

# %%
data3=pd.DataFrame()
data3["Equity"]=data.Equity.div(data.MARKET)
data3["KCB"]=data.KCB.div(data.MARKET)
data3["UCHUMI"]=data.UCHUMI.div(data.MARKET)
data3["BAMBURI"]=data.BAMBURI.div(data.MARKET)
data3["BAT"]=data.BAT.div(data.MARKET)
data3["SASINI"]=data.SASINI.div(data.MARKET)
data3["SAFAR"]=data.SAFAR.div(data.MARKET)
data3["NMG"]=data.NMG.div(data.MARKET)
data3["EABL"]=data.EABL.div(data.MARKET)
data3["SCB"]=data.SCB.div(data.MARKET)
data3["MARKET"]=data.MARKET

# %%
data.head(70)
# Out:
#     Equity   KCB  UCHUMI  BAMBURI   BAT  EABL  SASINI  SAFAR   NMG   SCB  \
# 0     4.72  4.35    2.00     5.00  5.83  1.87    6.69   2.87  3.16  4.11
# 1     4.93  4.23    2.02     5.00  5.52  1.84    6.56   2.64  3.18  4.08
# 2     4.48  4.23    2.08     5.00  5.52  1.90    6.25   2.70  3.18  4.44
# 3     4.14  4.02    2.08     5.00  5.81  1.94    5.57   2.49  3.09  4.11
# 4     3.89  3.67    2.48     5.12  5.70  2.12    5.28   2.82  3.16  4.25
# 5     3.30  3.70    2.39     5.12  6.00  2.12    1.45   2.62  3.23  4.25
# 6     3.28  3.54    2.32     5.07  5.96  2.26    1.45   2.63  3.24  4.36
# 7     3.21  3.51    2.40     5.07  5.60  2.25    1.47   2.72  3.30  4.19
# 8     3.02  3.48    2.41     5.10  6.40  2.08    1.47   2.64  3.18  4.19
# 9     3.26  3.45    3.33     5.34  6.25  2.12    1.41   2.57  3.17  4.14
# 10    2.97  3.42    3.26     5.31  6.00  2.12    1.44   2.46  3.15  4.15
# 11    3.00  3.45    3.21     5.42  5.97  2.04    1.44   2.52  3.18  4.07
# ...

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data3.index, data3.Equity)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('Equity Beta')
ax.set_title('Equity Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/equity.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data3.index, data3.KCB)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('KCB Beta')
ax.set_title('Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/kcb.png")

# %%
fig.savefig("/home/banga/Desktop/datamining/beta/equity.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data3.index, data3.BAT)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('BAT Beta')
ax.set_title('BAT Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/bat.png")

# %%
fig.savefig("/home/banga/Desktop/datamining/beta/nmg.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data3.index, data3.NMG)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('NMG Beta')
ax.set_title('NMG Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/nmg.png")

# %%
fig.savefig("/home/banga/Desktop/datamining/beta/equity.png")

# %%
fig.savefig("/home/banga/Desktop/datamining/beta/equity.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data3.index, data3.SAFAR)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('SAFARICOM Beta')
ax.set_title('SAFARICOM Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/safar.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data3.index, data3.SASINI)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('SASINI Beta')
ax.set_title('SASINI Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/sasini.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data3.index, data3.SCB)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('Standard Charted Bank Beta')
ax.set_title('SCB Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/scb.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data3.index, data3.UCHUMI)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('UCHUMI Beta')
ax.set_title('UCHUMI Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/uchumi.png")

# %%
data3.to_csv("/home/banga/Desktop/datamining/beta/data_method2.csv")

# %%
data4=pd.DataFrame()
data4["Equity"]=(data.Equity-data.Equity.mean())*(data.MARKET-data.MARKET.mean())
data4["KCB"]=(data.KCB-data.KCB.mean())*(data.MARKET-data.MARKET.mean())
data4["UCHUMI"]=(data.UCHUMI-data.UCHUMI.mean())*(data.MARKET-data.MARKET.mean())
data4["BAMBURI"]=(data.BAMBURI-data.BAMBURI.mean())*(data.MARKET-data.MARKET.mean())
data4["BAT"]=(data.BAT-data.BAT.mean())*(data.MARKET-data.MARKET.mean())
data4["EABL"]=(data.EABL-data.EABL.mean())*(data.MARKET-data.MARKET.mean())
data4["SASINI"]=(data.SASINI-data.SASINI.mean())*(data.MARKET-data.MARKET.mean())
data4["SAFAR"]=(data.SAFAR-data.SAFAR.mean())*(data.MARKET-data.MARKET.mean())
data4["NMG"]=(data.NMG-data.NMG.mean())*(data.MARKET-data.MARKET.mean())
data4["SCB"]=(data.SCB-data.SCB.mean())*(data.MARKET-data.MARKET.mean())

# %%
data4.to_csv("/home/banga/Desktop/datamining/beta/data_method_1_notbeta.csv")

# %%
data5=pd.DataFrame()
data5["Equity"]=data4.Equity.div(data.MARKET)
data5["KCB"]=data4.KCB.div(data.MARKET)
data5["UCHUMI"]=data4.UCHUMI.div(data.MARKET)
data5["BAMBURI"]=data4.BAMBURI.div(data.MARKET)
data5["BAT"]=data4.BAT.div(data.MARKET)
data5["SASINI"]=data4.SASINI.div(data.MARKET)
data5["SAFAR"]=data4.SAFAR.div(data.MARKET)
data5["NMG"]=data4.NMG.div(data.MARKET)
data5["SCB"]=data4.SCB.div(data.MARKET)
data5["EABL"]=data4.EABL.div(data.MARKET)
data5["MARKET"]=data.MARKET

# %%
data5.head()
# Out:
#      Equity       KCB    UCHUMI   BAMBURI       BAT    SASINI     SAFAR  \
# 0  0.027366  0.013033 -0.016441 -0.051443  0.013528  0.123999 -0.016806
# 1  0.014517  0.004370 -0.007032 -0.022725  0.002392  0.053274 -0.010083
# 2  0.004910  0.002303 -0.003341 -0.011978  0.001261  0.026191 -0.004949
# 3 -0.015682 -0.005658  0.018459  0.066182 -0.016730 -0.121823  0.034414
# 4 -0.005875  0.004952  0.004037  0.050245 -0.010533 -0.090605  0.018843
#
#         NMG       SCB      EABL  MARKET
# 0 -0.029151 -0.034343 -0.001942   4.060
# 1 -0.012646 -0.015518 -0.001204   4.000
# 2 -0.006666 -0.005986 -0.000269   3.978
# 3  0.039860  0.044183  0.000141   3.825
# 4  0.030323  0.031913 -0.004785   3.849

# %%
data5.mean()
# Out:
# Equity     0.039513
# KCB        0.029247
# UCHUMI     0.045873
# BAMBURI    0.052305
# BAT        0.015835
# SASINI     0.024284
# SAFAR      0.043159
# NMG        0.120823
# SCB        0.119486
# EABL       0.006620
# MARKET     3.953763
# dtype: float64

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.Equity)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('Equity Beta')
ax.set_title('Equity Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/equity1.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.KCB)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('KCB Beta')
ax.set_title('KCB Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/kcb1.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.BAMBURI)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('BAMBURI Beta')
ax.set_title('BAMBURI Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/bamburi1.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.BAT)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('BAT Beta')
ax.set_title('BAT Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/bat1.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.SASINI)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('Sasini Beta')
ax.set_title('Sasini Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/sasini1.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.SAFAR)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('Safaricom Beta')
ax.set_title('Safaricom Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/safaricom1.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.NMG)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('NMG Beta')
ax.set_title('NMG Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/nmg1.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.SCB)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('SCB Beta')
ax.set_title('SCB Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/scb1.png")

# %%
fig, ax= plt.subplots(figsize=(20,5))

ax.plot(data5.index, data5.EABL)
ax.set_xlabel('Time (Weeks)')
ax.set_ylabel('EABL Beta')
ax.set_title('EABL Beta Vs Time');
fig.savefig("/home/banga/Desktop/datamining/beta/eabl1.png")

# %%
np.sum([-1,3,4])
# Out:
# 6
